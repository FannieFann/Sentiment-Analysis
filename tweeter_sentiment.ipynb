# %% [markdown]
# # a7 - Tweeter Sentiment
#
# In this assignment you will write a program to perform simple [sentiment analysis](https://en.wikipedia.org/wiki/Sentiment_analysis) of Twitter data&mdash;that is, determining the "attitude" or "emotion" (e.g., how "positive", "negative", "joyful", etc) of tweets made by a particular Twitter user. Sentiment analysis is a fascinating field: researchers have shown that the "mood" of Twitter communication [reflects biological rhythms](http://www.nytimes.com/2011/09/30/science/30twitter.html) and can even be used to [predict the stock market](http://arxiv.org/pdf/1010.3003&embedded=true). The particular analysis you'll be performing is inspired by an investigation of [personal vs. organizational tweets](http://varianceexplained.org/r/trump-tweets/) (which has become less amusing over time).
#
# You will be implementing a Python program that performs this analysis on **real data** taken directly from a Twitter user's timeline. In the end, your script will produce output similar to the following:
#
# ```
# EMOTION       % WORDS  EXAMPLE WORDS                     HASHTAGS
# positive      6.16%    learn, faculty, happy             #accesstoinfoday, #indigenouspeoplesday, #idealistfair
# trust         3.08%    school, faculty, happy            #indigenouspeoplesday, #diversity
# anticipation  2.53%    happy, top, ready                 #indigenouspeoplesday, #informatics, #info340
# joy           1.76%    happy, peace, deal                #indigenouspeoplesday, #accesstoinfoday
# surprise      0.99%    deal, award, surprised            #suzzallolibrary, #nobrainer
# negative      0.88%    fall, rejection, outstanding
# sadness       0.55%    fall, rejection, problem
# disgust       0.44%    rejection, weird, finally
# fear          0.44%    rejection, surprise, problem
# anger         0.33%    rejection, disaster, involvement  #mlis
# ```
#
# (The "hashtags" column is optional extra credit).
#
# Fill in the below code cells as specified. Note that cells may utilize variables and functions defined in previous cells; we should be able to use the `Kernal > Restart & Clear All` menu item followed by `Cell > Run All` to execute your entire notebook and see the correct output.

# %% [markdown]
# ## The Data
# You'll be working with two different pieces of data for this assignment.

# %% [markdown]
# First, you'll be loading tweet data taken directly from [Twitter's API](https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline). You can find an example of this tweet data in the **`uw_ischool_sample.py`** file inside the `data/` folder. The below cell will import this data as a variable `SAMPLE_TWEETS` from the provided _module_ file:

# %%
# import from uw_ischool_sample file in the `data/` package (folder)
from data.uw_ischool_sample import SAMPLE_TWEETS

# %% [markdown]
# The data is represented as one giant **list of dictionaries**: the **list** contains a sequence of **dictionaries**, where each dictionary represents a tweet. Each dictionary contains many different _value_, some of which themselves may be dictionaries.
#
# Print out the first three elements from the `SAMPLE_TWEETS` list to see what information can be found. The most relevant value is the `"text"` of the tweet.
# - The Twitter API actually provides a lot more information about each tweet; I've stripped it down to only the most important properties for readability. Each dictionary is a proper subset of the full data you'd get from Twitter.
# - Because of the source of the sentiment data, your analysis will be biased and only support English-language speakers. Nevertheless, Twitter is an international community so you may encounter non-English characters and words. You'll be working with real-world data and it will be messy!

# %%
[d['text'] for d in SAMPLE_TWEETS[:3]]
# Out:
# ['RT @UWAPress: Happy #IndigenousPeoplesDay https://t.co/YmU9e9lj7v',
#  "We'll be at the #IdealistFair this evening on the Seattle U. campus. Come and learn about our graduate programs: https://t.co/et1HrQshmr",
#  'RT @iYouthUW: iYouth Tips for 1st\xa0Years https://t.co/K4SCIEhJ8k https://t.co/p4lbC6Jb5o']

# %% [markdown]
# The second piece of data you'll be working with is a set of **word-sentiments**&mdash;a list of English-language words and what emotions (e.g., "joy", "anger") [are associated with them](http://saifmohammad.com/WebPages/NRC-Emotion-Lexicon.htm).
#
# - The [`nltk`](https://github.com/nltk/nltk/wiki/Sentiment-Analysis) library you used in a previous assignment does support sentiment analysis. However, for practice and extendability you'll be doing a more "manual" analysis using the provided data file for this assignment.
#
# `import` the word sentiments as a variable **`SENTIMENTS`** from the **`data.sentiments_nrc`** module. You should also import the `EMOTIONS` variable provided by the same module: this is a _list_ of possible emotions. You can inspect the variables (e.g., print them out) to confirm that you have imported them.

# %%
from data.sentiments_nrc import SENTIMENTS
from data.sentiments_nrc import EMOTIONS

# %%
EMOTIONS
# Out:
# ['positive',
#  'negative',
#  'anger',
#  'anticipation',
#  'disgust',
#  'fear',
#  'joy',
#  'sadness',
#  'surprise',
#  'trust']

# %%
SENTIMENTS
# Out:
# {'abacus': {'trust': 1},
#  'abandon': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'abandoned': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'abandonment': {'surprise': 1,
#   'sadness': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'abba': {'positive': 1},
#  'abbot': {'trust': 1},
#  'abduction': {'sadness': 1, 'surprise': 1, 'fear': 1, 'negative': 1},
#  'aberrant': {'negative': 1},
#  'aberration': {'disgust': 1, 'negative': 1},
#  'abhor': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'abhorrent': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'ability': {'positive': 1},
#  'abject': {'disgust': 1, 'negative': 1},
#  'abnormal': {'disgust': 1, 'negative': 1},
#  'abolish': {'anger': 1, 'negative': 1},
#  'abolition': {'negative': 1},
#  'abominable': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'abomination': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'abort': {'negative': 1},
#  'abortion': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'abortive': {'sadness': 1, 'negative': 1},
#  'abovementioned': {'positive': 1},
#  'abrasion': {'negative': 1},
#  'abrogate': {'negative': 1},
#  'abrupt': {'surprise': 1},
#  'abscess': {'sadness': 1, 'negative': 1},
#  'absence': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'absent': {'sadness': 1, 'negative': 1},
#  'absentee': {'sadness': 1, 'negative': 1},
#  'absenteeism': {'negative': 1},
#  'absolute': {'positive': 1},
#  'absolution': {'positive': 1, 'joy': 1, 'trust': 1},
#  'absorbed': {'positive': 1},
#  'absurd': {'negative': 1},
#  'absurdity': {'negative': 1},
#  'abundance': {'disgust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'trust': 1,
#   'positive': 1,
#   'negative': 1},
#  'abundant': {'positive': 1, 'joy': 1},
#  'abuse': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'abysmal': {'sadness': 1, 'negative': 1},
#  'abyss': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'academic': {'positive': 1, 'trust': 1},
#  'academy': {'positive': 1},
#  'accelerate': {'anticipation': 1},
#  'acceptable': {'positive': 1},
#  'acceptance': {'positive': 1},
#  'accessible': {'positive': 1},
#  'accident': {'sadness': 1, 'surprise': 1, 'fear': 1, 'negative': 1},
#  'accidental': {'surprise': 1, 'fear': 1, 'negative': 1},
#  'accidentally': {'surprise': 1},
#  'accolade': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'accommodation': {'positive': 1},
#  'accompaniment': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'accomplish': {'positive': 1, 'joy': 1},
#  'accomplished': {'positive': 1, 'joy': 1},
#  'accomplishment': {'positive': 1},
#  'accord': {'positive': 1, 'trust': 1},
#  'account': {'trust': 1},
#  'accountability': {'positive': 1, 'trust': 1},
#  'accountable': {'positive': 1, 'trust': 1},
#  'accountant': {'trust': 1},
#  'accounts': {'trust': 1},
#  'accredited': {'positive': 1, 'trust': 1},
#  'accueil': {'positive': 1},
#  'accurate': {'positive': 1, 'trust': 1},
#  'accursed': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'accusation': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'accusative': {'negative': 1},
#  'accused': {'negative': 1, 'anger': 1, 'fear': 1},
#  'accuser': {'negative': 1, 'anger': 1, 'fear': 1},
#  'accusing': {'negative': 1, 'anger': 1, 'fear': 1},
#  'ace': {'positive': 1},
#  'ache': {'sadness': 1, 'negative': 1},
#  'achieve': {'positive': 1, 'joy': 1, 'trust': 1},
#  'achievement': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'aching': {'sadness': 1, 'negative': 1},
#  'acid': {'negative': 1},
#  'acknowledgment': {'positive': 1},
#  'acquire': {'positive': 1},
#  'acquiring': {'positive': 1, 'anticipation': 1},
#  'acrobat': {'positive': 1, 'joy': 1, 'fear': 1, 'trust': 1},
#  'action': {'positive': 1},
#  'actionable': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'actual': {'positive': 1},
#  'acuity': {'positive': 1},
#  'acumen': {'positive': 1},
#  'adapt': {'positive': 1},
#  'adaptable': {'positive': 1},
#  'adder': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'addiction': {'negative': 1},
#  'addresses': {'positive': 1, 'anticipation': 1},
#  'adept': {'positive': 1},
#  'adequacy': {'positive': 1},
#  'adhering': {'trust': 1},
#  'adipose': {'negative': 1},
#  'adjudicate': {'fear': 1, 'negative': 1},
#  'adjunct': {'positive': 1},
#  'administrative': {'trust': 1},
#  'admirable': {'positive': 1, 'joy': 1, 'trust': 1},
#  'admiral': {'positive': 1, 'trust': 1},
#  'admiration': {'positive': 1, 'joy': 1, 'trust': 1},
#  'admire': {'positive': 1, 'trust': 1},
#  'admirer': {'positive': 1},
#  'admissible': {'positive': 1, 'trust': 1},
#  'admonition': {'fear': 1, 'negative': 1},
#  'adorable': {'positive': 1, 'joy': 1},
#  'adoration': {'positive': 1, 'joy': 1, 'trust': 1},
#  'adore': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'adrift': {'sadness': 1, 'anticipation': 1, 'fear': 1, 'negative': 1},
#  'adulterated': {'negative': 1},
#  'adultery': {'sadness': 1, 'disgust': 1, 'negative': 1},
#  'advance': {'positive': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'fear': 1,
#   'surprise': 1},
#  'advanced': {'positive': 1},
#  'advancement': {'positive': 1},
#  'advantage': {'positive': 1},
#  'advantageous': {'positive': 1},
#  'advent': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'adventure': {'positive': 1, 'anticipation': 1},
#  'adventurous': {'positive': 1},
#  'adversary': {'anger': 1, 'negative': 1},
#  'adverse': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'adversity': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'advice': {'trust': 1},
#  'advisable': {'positive': 1, 'trust': 1},
#  'advise': {'positive': 1, 'trust': 1},
#  'advised': {'trust': 1},
#  'adviser': {'positive': 1, 'trust': 1},
#  'advocacy': {'positive': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'anger': 1,
#   'trust': 1},
#  'advocate': {'trust': 1},
#  'aesthetic': {'positive': 1},
#  'aesthetics': {'positive': 1, 'joy': 1},
#  'affable': {'positive': 1},
#  'affection': {'positive': 1, 'joy': 1, 'trust': 1},
#  'affiliated': {'positive': 1},
#  'affirm': {'positive': 1, 'trust': 1},
#  'affirmation': {'positive': 1},
#  'affirmative': {'positive': 1},
#  'affirmatively': {'positive': 1, 'trust': 1},
#  'afflict': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'afflicted': {'negative': 1},
#  'affliction': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'affluence': {'positive': 1, 'joy': 1},
#  'affluent': {'positive': 1},
#  'afford': {'positive': 1},
#  'affront': {'sadness': 1,
#   'anger': 1,
#   'surprise': 1,
#   'fear': 1,
#   'disgust': 1,
#   'negative': 1},
#  'afraid': {'fear': 1, 'negative': 1},
#  'aftermath': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'aftertaste': {'negative': 1},
#  'aga': {'positive': 1, 'fear': 1, 'trust': 1},
#  'aggravated': {'anger': 1, 'negative': 1},
#  'aggravating': {'sadness': 1, 'anger': 1, 'negative': 1},
#  'aggravation': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'aggression': {'negative': 1, 'anger': 1, 'fear': 1},
#  'aggressive': {'negative': 1, 'anger': 1, 'fear': 1},
#  'aggressor': {'negative': 1, 'anger': 1, 'fear': 1},
#  'aghast': {'disgust': 1, 'surprise': 1, 'fear': 1, 'negative': 1},
#  'agile': {'positive': 1},
#  'agility': {'positive': 1},
#  'agitated': {'anger': 1, 'negative': 1},
#  'agitation': {'anger': 1, 'negative': 1},
#  'agonizing': {'fear': 1, 'negative': 1},
#  'agony': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'agree': {'positive': 1},
#  'agreeable': {'positive': 1, 'trust': 1},
#  'agreed': {'positive': 1, 'trust': 1},
#  'agreeing': {'positive': 1, 'trust': 1},
#  'agreement': {'positive': 1, 'trust': 1},
#  'agriculture': {'positive': 1},
#  'aground': {'negative': 1},
#  'ahead': {'positive': 1},
#  'aid': {'positive': 1},
#  'aiding': {'positive': 1},
#  'ail': {'sadness': 1, 'negative': 1},
#  'ailing': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'aimless': {'negative': 1},
#  'airport': {'anticipation': 1},
#  'airs': {'disgust': 1, 'negative': 1},
#  'akin': {'trust': 1},
#  'alabaster': {'positive': 1},
#  'alarm': {'surprise': 1, 'fear': 1, 'negative': 1},
#  'alarming': {'surprise': 1, 'fear': 1, 'negative': 1},
#  'alb': {'trust': 1},
#  'alcoholism': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'alertness': {'positive': 1, 'anticipation': 1, 'fear': 1, 'surprise': 1},
#  'alerts': {'anticipation': 1, 'fear': 1, 'surprise': 1},
#  'alien': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'alienate': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'alienated': {'sadness': 1, 'negative': 1},
#  'alienation': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'alimentation': {'positive': 1},
#  'alimony': {'negative': 1},
#  'alive': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'allay': {'positive': 1},
#  'allegation': {'anger': 1, 'negative': 1},
#  'allege': {'negative': 1},
#  'allegiance': {'positive': 1, 'trust': 1},
#  'allegro': {'positive': 1},
#  'alleviate': {'positive': 1},
#  'alleviation': {'positive': 1},
#  'alliance': {'trust': 1},
#  'allied': {'positive': 1, 'trust': 1},
#  'allowable': {'positive': 1},
#  'allure': {'positive': 1, 'anticipation': 1, 'joy': 1, 'surprise': 1},
#  'alluring': {'positive': 1},
#  'ally': {'positive': 1, 'trust': 1},
#  'almighty': {'positive': 1},
#  'aloha': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'aloof': {'negative': 1},
#  'altercation': {'anger': 1, 'negative': 1},
#  'amaze': {'surprise': 1},
#  'amazingly': {'positive': 1, 'joy': 1, 'surprise': 1},
#  'ambassador': {'positive': 1, 'trust': 1},
#  'ambiguous': {'negative': 1},
#  'ambition': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'ambulance': {'fear': 1, 'trust': 1},
#  'ambush': {'surprise': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'ameliorate': {'positive': 1},
#  'amen': {'positive': 1, 'joy': 1, 'trust': 1},
#  'amenable': {'positive': 1},
#  'amend': {'positive': 1},
#  'amends': {'positive': 1},
#  'amenity': {'positive': 1},
#  'amiable': {'positive': 1},
#  'amicable': {'positive': 1, 'joy': 1},
#  'ammonia': {'disgust': 1},
#  'amnesia': {'negative': 1},
#  'amnesty': {'positive': 1, 'joy': 1},
#  'amortization': {'trust': 1},
#  'amour': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'amphetamines': {'disgust': 1, 'negative': 1},
#  'amuse': {'positive': 1, 'joy': 1},
#  'amused': {'positive': 1, 'joy': 1},
#  'amusement': {'positive': 1, 'joy': 1},
#  'amusing': {'positive': 1, 'joy': 1},
#  'anaconda': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'anal': {'negative': 1},
#  'analyst': {'positive': 1, 'anticipation': 1, 'trust': 1},
#  'anarchism': {'negative': 1, 'anger': 1, 'fear': 1},
#  'anarchist': {'negative': 1, 'anger': 1, 'fear': 1},
#  'anarchy': {'negative': 1, 'anger': 1, 'fear': 1},
#  'anathema': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'ancestral': {'trust': 1},
#  'anchor': {'positive': 1},
#  'anchorage': {'positive': 1, 'sadness': 1},
#  'ancient': {'negative': 1},
#  'angel': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'angelic': {'positive': 1, 'joy': 1, 'trust': 1},
#  'anger': {'anger': 1, 'negative': 1},
#  'angina': {'fear': 1, 'negative': 1},
#  'angling': {'anticipation': 1, 'negative': 1},
#  'angry': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'anguish': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'animate': {'positive': 1},
#  'animated': {'positive': 1, 'joy': 1},
#  'animosity': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'animus': {'anger': 1, 'negative': 1},
#  'annihilate': {'negative': 1, 'anger': 1, 'fear': 1},
#  'annihilated': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'annihilation': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'announcement': {'anticipation': 1},
#  'annoy': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'annoyance': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'annoying': {'anger': 1, 'negative': 1},
#  'annul': {'negative': 1},
#  'annulment': {'sadness': 1, 'negative': 1},
#  'anomaly': {'surprise': 1, 'fear': 1, 'negative': 1},
#  'anonymous': {'negative': 1},
#  'answerable': {'trust': 1},
#  'antagonism': {'anger': 1, 'negative': 1},
#  'antagonist': {'anger': 1, 'negative': 1},
#  'antagonistic': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'anthrax': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'antibiotics': {'positive': 1},
#  'antichrist': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'anticipation': {'anticipation': 1},
#  'anticipatory': {'anticipation': 1},
#  'antidote': {'positive': 1, 'anticipation': 1, 'trust': 1},
#  'antifungal': {'positive': 1, 'trust': 1},
#  'antipathy': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'antiquated': {'negative': 1},
#  'antique': {'positive': 1},
#  'antiseptic': {'positive': 1, 'trust': 1},
#  'antisocial': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'antithesis': {'anger': 1, 'negative': 1},
#  'anxiety': {'sadness': 1,
#   'anticipation': 1,
#   'anger': 1,
#   'negative': 1,
#   'fear': 1},
#  'anxious': {'anticipation': 1, 'fear': 1, 'negative': 1},
#  'apache': {'fear': 1, 'negative': 1},
#  'apathetic': {'sadness': 1, 'negative': 1},
#  'apathy': {'sadness': 1, 'negative': 1},
#  'aphid': {'disgust': 1, 'negative': 1},
#  'aplomb': {'positive': 1},
#  'apologetic': {'positive': 1, 'trust': 1},
#  'apologize': {'positive': 1, 'sadness': 1, 'trust': 1},
#  'apology': {'positive': 1},
#  'apostle': {'positive': 1, 'trust': 1},
#  'apostolic': {'trust': 1},
#  'appalling': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'apparition': {'fear': 1, 'surprise': 1},
#  'appeal': {'anticipation': 1},
#  'appendicitis': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'applause': {'positive': 1, 'trust': 1, 'joy': 1, 'surprise': 1},
#  'applicant': {'anticipation': 1},
#  'appreciation': {'positive': 1, 'joy': 1, 'trust': 1},
#  'apprehend': {'fear': 1},
#  'apprehension': {'fear': 1, 'negative': 1},
#  'apprehensive': {'anticipation': 1, 'fear': 1, 'negative': 1},
#  'apprentice': {'trust': 1},
#  'approaching': {'anticipation': 1},
#  'approbation': {'positive': 1, 'trust': 1},
#  'appropriation': {'negative': 1},
#  'approval': {'positive': 1},
#  'approve': {'positive': 1, 'joy': 1, 'trust': 1},
#  'approving': {'positive': 1},
#  'apt': {'positive': 1},
#  'aptitude': {'positive': 1},
#  'arbiter': {'trust': 1},
#  'arbitration': {'anticipation': 1},
#  'arbitrator': {'trust': 1},
#  'archaeology': {'positive': 1, 'anticipation': 1},
#  'archaic': {'negative': 1},
#  'architecture': {'trust': 1},
#  'ardent': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'ardor': {'positive': 1},
#  'arduous': {'negative': 1},
#  'argue': {'anger': 1, 'negative': 1},
#  'argument': {'anger': 1, 'negative': 1},
#  'argumentation': {'anger': 1},
#  'argumentative': {'negative': 1},
#  'arguments': {'anger': 1},
#  'arid': {'sadness': 1, 'negative': 1},
#  'aristocracy': {'positive': 1},
#  'aristocratic': {'positive': 1},
#  'armament': {'anger': 1, 'fear': 1},
#  'armaments': {'fear': 1, 'negative': 1},
#  'armed': {'positive': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'armor': {'positive': 1, 'fear': 1, 'trust': 1},
#  'armored': {'fear': 1},
#  'armory': {'trust': 1},
#  'aroma': {'positive': 1},
#  'arouse': {'positive': 1, 'anticipation': 1},
#  'arraignment': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'array': {'positive': 1},
#  'arrears': {'negative': 1},
#  'arrest': {'negative': 1},
#  'arrival': {'anticipation': 1},
#  'arrive': {'anticipation': 1},
#  'arrogance': {'negative': 1},
#  'arrogant': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'arsenic': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'arson': {'negative': 1, 'anger': 1, 'fear': 1},
#  'art': {'positive': 1,
#   'sadness': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'articulate': {'positive': 1},
#  'articulation': {'positive': 1},
#  'artillery': {'fear': 1, 'negative': 1},
#  'artisan': {'positive': 1},
#  'artiste': {'positive': 1},
#  'artistic': {'positive': 1},
#  'ascendancy': {'positive': 1},
#  'ascent': {'positive': 1},
#  'ash': {'negative': 1},
#  'ashamed': {'sadness': 1, 'disgust': 1, 'negative': 1},
#  'ashes': {'sadness': 1, 'negative': 1},
#  'asp': {'fear': 1},
#  'aspiration': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'aspire': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'aspiring': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'ass': {'negative': 1},
#  'assail': {'surprise': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'assailant': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'assassin': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'assassinate': {'negative': 1, 'anger': 1, 'fear': 1},
#  'assassination': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'assault': {'negative': 1, 'anger': 1, 'fear': 1},
#  'assembly': {'positive': 1, 'trust': 1},
#  'assent': {'positive': 1},
#  'asserting': {'positive': 1, 'trust': 1},
#  'assessment': {'trust': 1, 'surprise': 1},
#  'assessor': {'trust': 1},
#  'assets': {'positive': 1},
#  'asshole': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'assignee': {'trust': 1},
#  'assist': {'positive': 1, 'trust': 1},
#  'assistance': {'positive': 1},
#  'associate': {'positive': 1, 'trust': 1},
#  'association': {'trust': 1},
#  'assuage': {'positive': 1},
#  'assurance': {'positive': 1, 'trust': 1},
#  'assure': {'trust': 1},
#  'assured': {'positive': 1, 'trust': 1},
#  'assuredly': {'trust': 1},
#  'astonishingly': {'positive': 1, 'surprise': 1},
#  'astonishment': {'positive': 1, 'joy': 1, 'surprise': 1},
#  'astray': {'fear': 1, 'negative': 1},
#  'astringent': {'negative': 1},
#  'astrologer': {'positive': 1, 'anticipation': 1},
#  'astronaut': {'positive': 1},
#  'astronomer': {'positive': 1, 'anticipation': 1},
#  'astute': {'positive': 1},
#  'asylum': {'fear': 1, 'negative': 1},
#  'asymmetry': {'disgust': 1},
#  'atheism': {'negative': 1},
#  'atherosclerosis': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'athlete': {'positive': 1},
#  'athletic': {'positive': 1},
#  'atom': {'positive': 1},
#  'atone': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'atonement': {'positive': 1},
#  'atrocious': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'atrocity': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'atrophy': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'attachment': {'positive': 1},
#  'attack': {'negative': 1, 'anger': 1, 'fear': 1},
#  'attacking': {'sadness': 1,
#   'anger': 1,
#   'surprise': 1,
#   'fear': 1,
#   'disgust': 1,
#   'negative': 1},
#  'attainable': {'positive': 1, 'anticipation': 1},
#  'attainment': {'positive': 1},
#  'attempt': {'anticipation': 1},
#  'attendance': {'anticipation': 1},
#  'attendant': {'positive': 1, 'trust': 1},
#  'attention': {'positive': 1},
#  'attentive': {'positive': 1, 'trust': 1},
#  'attenuated': {'negative': 1},
#  'attenuation': {'sadness': 1, 'negative': 1},
#  'attest': {'positive': 1, 'trust': 1},
#  'attestation': {'trust': 1},
#  'attorney': {'positive': 1, 'trust': 1, 'anger': 1, 'fear': 1},
#  'attraction': {'positive': 1},
#  'attractiveness': {'positive': 1},
#  'auction': {'anticipation': 1},
#  'audacity': {'negative': 1},
#  'audience': {'anticipation': 1},
#  'auditor': {'fear': 1, 'trust': 1},
#  'augment': {'positive': 1},
#  'august': {'positive': 1},
#  'aunt': {'positive': 1, 'trust': 1},
#  'aura': {'positive': 1},
#  'auspicious': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'austere': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'austerity': {'negative': 1},
#  'authentic': {'positive': 1, 'joy': 1, 'trust': 1},
#  'authenticate': {'trust': 1},
#  'authentication': {'trust': 1},
#  'authenticity': {'positive': 1, 'trust': 1},
#  'author': {'positive': 1, 'trust': 1},
#  'authoritative': {'positive': 1, 'trust': 1},
#  'authority': {'positive': 1, 'trust': 1},
#  'authorization': {'positive': 1, 'trust': 1},
#  'authorize': {'trust': 1},
#  'authorized': {'positive': 1},
#  'autocratic': {'negative': 1},
#  'automatic': {'trust': 1},
#  'autopsy': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'avalanche': {'sadness': 1, 'surprise': 1, 'fear': 1, 'negative': 1},
#  'avarice': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'avatar': {'positive': 1},
#  'avenger': {'anger': 1, 'negative': 1},
#  'averse': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'aversion': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'avoid': {'fear': 1, 'negative': 1},
#  'avoidance': {'fear': 1, 'negative': 1},
#  'avoiding': {'fear': 1},
#  'await': {'anticipation': 1},
#  'award': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'awful': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'awkwardness': {'disgust': 1, 'negative': 1},
#  'awry': {'negative': 1},
#  'axiom': {'trust': 1},
#  'axiomatic': {'trust': 1},
#  'ay': {'positive': 1},
#  'aye': {'positive': 1},
#  'babble': {'negative': 1},
#  'babbling': {'negative': 1},
#  'baboon': {'disgust': 1, 'negative': 1},
#  'baby': {'positive': 1, 'joy': 1},
#  'babysitter': {'trust': 1},
#  'baccalaureate': {'positive': 1},
#  'backbone': {'positive': 1, 'anger': 1, 'trust': 1},
#  'backer': {'trust': 1},
#  'backward': {'negative': 1},
#  'backwards': {'disgust': 1, 'negative': 1},
#  'backwater': {'sadness': 1, 'negative': 1},
#  'bacteria': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'bacterium': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'bad': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'badge': {'trust': 1},
#  'badger': {'anger': 1, 'negative': 1},
#  'badly': {'sadness': 1, 'negative': 1},
#  'badness': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bailiff': {'trust': 1, 'fear': 1, 'negative': 1},
#  'bait': {'trust': 1, 'fear': 1, 'negative': 1},
#  'balance': {'positive': 1},
#  'balanced': {'positive': 1},
#  'bale': {'fear': 1, 'negative': 1},
#  'balk': {'negative': 1},
#  'ballad': {'positive': 1},
#  'ballet': {'positive': 1},
#  'ballot': {'positive': 1, 'anticipation': 1, 'trust': 1},
#  'balm': {'positive': 1, 'anticipation': 1, 'joy': 1, 'negative': 1},
#  'balsam': {'positive': 1},
#  'ban': {'negative': 1},
#  'bandit': {'negative': 1},
#  'bane': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bang': {'sadness': 1,
#   'anger': 1,
#   'surprise': 1,
#   'fear': 1,
#   'disgust': 1,
#   'negative': 1},
#  'banger': {'surprise': 1,
#   'anticipation': 1,
#   'anger': 1,
#   'negative': 1,
#   'fear': 1},
#  'banish': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'banished': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'banishment': {'sadness': 1, 'disgust': 1, 'anger': 1, 'negative': 1},
#  'bank': {'trust': 1},
#  'banker': {'trust': 1},
#  'bankrupt': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'bankruptcy': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'banquet': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'banshee': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'baptism': {'positive': 1},
#  'baptismal': {'positive': 1, 'joy': 1},
#  'barb': {'anger': 1, 'negative': 1},
#  'barbarian': {'fear': 1, 'negative': 1},
#  'barbaric': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'barbarism': {'negative': 1},
#  'bard': {'positive': 1},
#  'barf': {'disgust': 1},
#  'bargain': {'positive': 1, 'trust': 1},
#  'bark': {'anger': 1, 'negative': 1},
#  'barred': {'negative': 1},
#  'barren': {'sadness': 1, 'negative': 1},
#  'barricade': {'fear': 1, 'negative': 1},
#  'barrier': {'anger': 1, 'negative': 1},
#  'barrow': {'disgust': 1},
#  'bartender': {'trust': 1},
#  'barter': {'trust': 1},
#  'base': {'trust': 1},
#  'baseless': {'negative': 1},
#  'basketball': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'bastard': {'sadness': 1, 'disgust': 1, 'negative': 1},
#  'bastion': {'positive': 1, 'anger': 1},
#  'bath': {'positive': 1},
#  'battalion': {'anger': 1},
#  'batter': {'negative': 1, 'anger': 1, 'fear': 1},
#  'battered': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'battery': {'anger': 1, 'negative': 1},
#  'battle': {'anger': 1, 'negative': 1},
#  'battled': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'battlefield': {'fear': 1, 'negative': 1},
#  'bawdy': {'negative': 1},
#  'bayonet': {'negative': 1, 'anger': 1, 'fear': 1},
#  'beach': {'joy': 1},
#  'beam': {'positive': 1, 'joy': 1},
#  'beaming': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'bear': {'anger': 1, 'fear': 1},
#  'bearer': {'negative': 1},
#  'bearish': {'anger': 1, 'fear': 1},
#  'beast': {'negative': 1, 'anger': 1, 'fear': 1},
#  'beastly': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'beating': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'beautification': {'positive': 1, 'joy': 1, 'trust': 1},
#  'beautiful': {'positive': 1, 'joy': 1},
#  'beautify': {'positive': 1, 'joy': 1},
#  'beauty': {'positive': 1, 'joy': 1},
#  'bedrock': {'positive': 1, 'trust': 1},
#  'bee': {'anger': 1, 'fear': 1},
#  'beer': {'positive': 1, 'joy': 1},
#  'befall': {'negative': 1},
#  'befitting': {'positive': 1},
#  'befriend': {'positive': 1, 'joy': 1, 'trust': 1},
#  'beg': {'sadness': 1, 'negative': 1},
#  'beggar': {'sadness': 1, 'negative': 1},
#  'begging': {'negative': 1},
#  'begun': {'anticipation': 1},
#  'behemoth': {'fear': 1, 'negative': 1},
#  'beholden': {'negative': 1},
#  'belated': {'negative': 1},
#  'believed': {'trust': 1},
#  'believer': {'trust': 1},
#  'believing': {'positive': 1, 'trust': 1},
#  'belittle': {'sadness': 1,
#   'disgust': 1,
#   'negative': 1,
#   'anger': 1,
#   'fear': 1},
#  'belligerent': {'negative': 1, 'anger': 1, 'fear': 1},
#  'bellows': {'anger': 1},
#  'belt': {'negative': 1, 'anger': 1, 'fear': 1},
#  'bender': {'negative': 1},
#  'benefactor': {'positive': 1, 'trust': 1},
#  'beneficial': {'positive': 1},
#  'benefit': {'positive': 1},
#  'benevolence': {'positive': 1, 'joy': 1, 'trust': 1},
#  'benign': {'positive': 1, 'joy': 1},
#  'bequest': {'trust': 1},
#  'bereaved': {'sadness': 1, 'negative': 1},
#  'bereavement': {'sadness': 1, 'negative': 1},
#  'bereft': {'negative': 1},
#  'berserk': {'anger': 1, 'negative': 1},
#  'berth': {'positive': 1},
#  'bestial': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'betray': {'sadness': 1,
#   'disgust': 1,
#   'surprise': 1,
#   'anger': 1,
#   'negative': 1},
#  'betrayal': {'sadness': 1, 'disgust': 1, 'anger': 1, 'negative': 1},
#  'betrothed': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'betterment': {'positive': 1},
#  'beverage': {'positive': 1},
#  'beware': {'anticipation': 1, 'fear': 1, 'negative': 1},
#  'bewildered': {'surprise': 1, 'fear': 1, 'negative': 1},
#  'bewilderment': {'fear': 1, 'surprise': 1},
#  'bias': {'anger': 1, 'negative': 1},
#  'biased': {'negative': 1},
#  'biblical': {'positive': 1},
#  'bickering': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'biennial': {'anticipation': 1},
#  'bier': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'bigot': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bigoted': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bile': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'bilingual': {'positive': 1},
#  'biopsy': {'fear': 1, 'negative': 1},
#  'birch': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'birth': {'positive': 1, 'anticipation': 1, 'joy': 1, 'fear': 1, 'trust': 1},
#  'birthday': {'positive': 1, 'anticipation': 1, 'joy': 1, 'surprise': 1},
#  'birthplace': {'anger': 1, 'negative': 1},
#  'bitch': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bite': {'negative': 1},
#  'bitterly': {'sadness': 1, 'disgust': 1, 'anger': 1, 'negative': 1},
#  'bitterness': {'sadness': 1, 'disgust': 1, 'anger': 1, 'negative': 1},
#  'bizarre': {'negative': 1, 'surprise': 1},
#  'black': {'sadness': 1, 'negative': 1},
#  'blackjack': {'negative': 1},
#  'blackmail': {'negative': 1, 'anger': 1, 'fear': 1},
#  'blackness': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'blame': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'blameless': {'positive': 1},
#  'bland': {'negative': 1},
#  'blanket': {'trust': 1},
#  'blasphemous': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'blasphemy': {'anger': 1, 'negative': 1},
#  'blast': {'surprise': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'blatant': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'blather': {'negative': 1},
#  'blaze': {'anger': 1, 'negative': 1},
#  'bleak': {'sadness': 1, 'negative': 1},
#  'bleeding': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'blemish': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bless': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'blessed': {'positive': 1, 'joy': 1},
#  'blessing': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'blessings': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'blight': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'blighted': {'sadness': 1, 'disgust': 1, 'negative': 1},
#  'blind': {'negative': 1},
#  'blinded': {'negative': 1},
#  'blindfold': {'anticipation': 1, 'fear': 1, 'surprise': 1},
#  'blindly': {'sadness': 1, 'negative': 1},
#  'blindness': {'sadness': 1, 'negative': 1},
#  'bliss': {'positive': 1, 'joy': 1},
#  'blissful': {'positive': 1, 'joy': 1},
#  'blister': {'disgust': 1, 'negative': 1},
#  'blitz': {'surprise': 1},
#  'bloated': {'disgust': 1, 'negative': 1},
#  'blob': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'blockade': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bloodless': {'positive': 1},
#  'bloodshed': {'sadness': 1,
#   'anger': 1,
#   'surprise': 1,
#   'fear': 1,
#   'disgust': 1,
#   'negative': 1},
#  'bloodthirsty': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bloody': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bloom': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'blossom': {'positive': 1, 'joy': 1},
#  'blot': {'negative': 1},
#  'blower': {'negative': 1},
#  'blowout': {'negative': 1},
#  'blue': {'sadness': 1},
#  'blues': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'bluff': {'negative': 1},
#  'blunder': {'sadness': 1, 'disgust': 1, 'negative': 1},
#  'blur': {'negative': 1},
#  'blurred': {'negative': 1},
#  'blush': {'negative': 1},
#  'board': {'anticipation': 1},
#  'boast': {'positive': 1, 'negative': 1},
#  'boasting': {'negative': 1},
#  'bodyguard': {'positive': 1, 'trust': 1},
#  'bog': {'negative': 1},
#  'bogus': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'boil': {'disgust': 1, 'negative': 1},
#  'boilerplate': {'negative': 1},
#  'boisterous': {'positive': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'anger': 1,
#   'negative': 1},
#  'bold': {'positive': 1},
#  'boldness': {'positive': 1},
#  'bolster': {'positive': 1},
#  'bomb': {'surprise': 1, 'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bombard': {'negative': 1, 'anger': 1, 'fear': 1},
#  'bombardment': {'negative': 1, 'anger': 1, 'fear': 1},
#  'bombed': {'disgust': 1, 'negative': 1},
#  'bomber': {'sadness': 1, 'fear': 1},
#  'bonanza': {'positive': 1, 'joy': 1},
#  'bondage': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'bonds': {'negative': 1},
#  'bonne': {'positive': 1},
#  'bonus': {'positive': 1, 'anticipation': 1, 'joy': 1, 'surprise': 1},
#  'boo': {'negative': 1},
#  'booby': {'negative': 1},
#  'bookish': {'positive': 1},
#  'bookshop': {'positive': 1},
#  'bookworm': {'positive': 1, 'negative': 1},
#  'boomerang': {'anticipation': 1, 'trust': 1},
#  'boon': {'positive': 1},
#  'booze': {'negative': 1},
#  'bore': {'negative': 1},
#  'boredom': {'sadness': 1, 'negative': 1},
#  'boring': {'negative': 1},
#  'borrower': {'negative': 1},
#  'bother': {'negative': 1},
#  'bothering': {'sadness': 1, 'anger': 1, 'negative': 1},
#  'bottom': {'sadness': 1, 'negative': 1},
#  'bottomless': {'fear': 1},
#  'bound': {'negative': 1},
#  'bountiful': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'bounty': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'bouquet': {'positive': 1, 'joy': 1, 'trust': 1},
#  'bout': {'anger': 1, 'negative': 1},
#  'bovine': {'disgust': 1, 'negative': 1},
#  'bowels': {'disgust': 1},
#  'boxing': {'anger': 1},
#  'boy': {'disgust': 1, 'negative': 1},
#  'boycott': {'negative': 1},
#  'brag': {'negative': 1},
#  'brains': {'positive': 1},
#  'bran': {'disgust': 1},
#  'brandy': {'negative': 1},
#  'bravado': {'negative': 1},
#  'bravery': {'positive': 1},
#  'brawl': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'brazen': {'anger': 1, 'negative': 1},
#  'breach': {'negative': 1},
#  'break': {'surprise': 1},
#  'breakdown': {'negative': 1},
#  'breakfast': {'positive': 1},
#  'breakneck': {'negative': 1},
#  'breakup': {'sadness': 1, 'negative': 1},
#  'bribe': {'negative': 1},
#  'bribery': {'disgust': 1, 'negative': 1},
#  'bridal': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'bride': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'bridegroom': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'bridesmaid': {'positive': 1, 'joy': 1, 'trust': 1},
#  'brigade': {'fear': 1, 'negative': 1},
#  'brighten': {'positive': 1, 'trust': 1, 'joy': 1, 'surprise': 1},
#  'brightness': {'positive': 1},
#  'brilliant': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'brimstone': {'negative': 1, 'anger': 1, 'fear': 1},
#  'bristle': {'negative': 1},
#  'broadside': {'anticipation': 1, 'negative': 1},
#  'brocade': {'positive': 1},
#  'broil': {'anger': 1, 'negative': 1},
#  'broke': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'broken': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'brothel': {'disgust': 1, 'negative': 1},
#  'brother': {'positive': 1, 'trust': 1},
#  'brotherhood': {'positive': 1, 'trust': 1},
#  'brotherly': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'bruise': {'anticipation': 1, 'negative': 1},
#  'brunt': {'anger': 1, 'negative': 1},
#  'brutal': {'negative': 1, 'anger': 1, 'fear': 1},
#  'brutality': {'negative': 1, 'anger': 1, 'fear': 1},
#  'brute': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'buck': {'positive': 1, 'surprise': 1, 'fear': 1, 'negative': 1},
#  'buddy': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'budget': {'trust': 1},
#  'buffet': {'anger': 1, 'negative': 1},
#  'bug': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'bugaboo': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'bugle': {'anticipation': 1},
#  'build': {'positive': 1},
#  'building': {'positive': 1},
#  'bulbous': {'negative': 1},
#  'bulldog': {'positive': 1},
#  'bulletproof': {'positive': 1},
#  'bully': {'negative': 1, 'anger': 1, 'fear': 1},
#  'bum': {'sadness': 1, 'disgust': 1, 'negative': 1},
#  'bummer': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'bunker': {'fear': 1},
#  'buoy': {'positive': 1},
#  'burdensome': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'bureaucracy': {'negative': 1, 'trust': 1},
#  'bureaucrat': {'disgust': 1, 'negative': 1},
#  'burglar': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'burglary': {'negative': 1},
#  'burial': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'buried': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'burke': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'burlesque': {'surprise': 1},
#  'burnt': {'disgust': 1, 'negative': 1},
#  'bursary': {'trust': 1},
#  'bury': {'sadness': 1},
#  'buss': {'positive': 1, 'joy': 1},
#  'busted': {'negative': 1, 'anger': 1, 'fear': 1},
#  'butcher': {'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'butler': {'positive': 1, 'trust': 1},
#  'butt': {'negative': 1},
#  'buttery': {'positive': 1},
#  'buxom': {'positive': 1},
#  'buzz': {'positive': 1, 'anticipation': 1, 'fear': 1},
#  'buzzed': {'negative': 1},
#  'bye': {'anticipation': 1},
#  'bylaw': {'trust': 1},
#  'cab': {'positive': 1},
#  'cabal': {'fear': 1, 'negative': 1},
#  'cabinet': {'positive': 1, 'trust': 1},
#  'cable': {'surprise': 1},
#  'cacophony': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'cad': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'cadaver': {'sadness': 1,
#   'disgust': 1,
#   'surprise': 1,
#   'fear': 1,
#   'negative': 1},
#  'cafe': {'positive': 1},
#  'cage': {'sadness': 1, 'negative': 1},
#  'calamity': {'sadness': 1},
#  'calculating': {'negative': 1},
#  'calculation': {'anticipation': 1},
#  'calculator': {'positive': 1, 'trust': 1},
#  'calf': {'positive': 1, 'joy': 1, 'trust': 1},
#  'callous': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'calls': {'anticipation': 1, 'negative': 1, 'trust': 1},
#  'calm': {'positive': 1},
#  'camouflage': {'surprise': 1},
#  'camouflaged': {'surprise': 1},
#  'campaigning': {'negative': 1, 'anger': 1, 'fear': 1},
#  'canary': {'positive': 1},
#  'cancel': {'sadness': 1, 'negative': 1},
#  'cancer': {'sadness': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'candid': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'candidate': {'positive': 1},
#  'candied': {'positive': 1},
#  'cane': {'anger': 1, 'fear': 1},
#  'canker': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'cannibal': {'disgust': 1, 'fear': 1, 'negative': 1},
#  'cannibalism': {'disgust': 1, 'negative': 1},
#  'cannon': {'negative': 1, 'anger': 1, 'fear': 1},
#  'canons': {'trust': 1},
#  'cap': {'anticipation': 1, 'trust': 1},
#  'capitalist': {'positive': 1},
#  'captain': {'positive': 1},
#  'captivate': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'captivating': {'positive': 1},
#  'captive': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'captivity': {'sadness': 1, 'negative': 1},
#  'captor': {'fear': 1, 'negative': 1},
#  'capture': {'negative': 1},
#  'carcass': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'carcinoma': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'cardiomyopathy': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'career': {'positive': 1, 'anticipation': 1},
#  'careful': {'positive': 1},
#  'carefully': {'positive': 1},
#  'carelessness': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'caress': {'positive': 1},
#  'caretaker': {'positive': 1, 'trust': 1},
#  'caricature': {'negative': 1},
#  'caries': {'disgust': 1, 'negative': 1},
#  'carnage': {'sadness': 1,
#   'anger': 1,
#   'surprise': 1,
#   'fear': 1,
#   'disgust': 1,
#   'negative': 1},
#  'carnal': {'negative': 1},
#  'carnivorous': {'fear': 1, 'negative': 1},
#  'carol': {'positive': 1, 'joy': 1, 'trust': 1},
#  'cartel': {'negative': 1},
#  'cartridge': {'fear': 1},
#  'cascade': {'positive': 1},
#  'case': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'cash': {'anticipation': 1,
#   'joy': 1,
#   'trust': 1,
#   'positive': 1,
#   'anger': 1,
#   'fear': 1},
#  'cashier': {'trust': 1},
#  'casket': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'caste': {'negative': 1},
#  'casualty': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'cataract': {'sadness': 1, 'anticipation': 1, 'fear': 1, 'negative': 1},
#  'catastrophe': {'sadness': 1,
#   'anger': 1,
#   'surprise': 1,
#   'fear': 1,
#   'disgust': 1,
#   'negative': 1},
#  'catch': {'surprise': 1},
#  'catechism': {'disgust': 1},
#  'categorical': {'positive': 1},
#  'cater': {'positive': 1},
#  'cathartic': {'positive': 1},
#  'cathedral': {'positive': 1, 'joy': 1, 'trust': 1},
#  'catheter': {'negative': 1},
#  'caution': {'anticipation': 1, 'anger': 1, 'negative': 1, 'fear': 1},
#  'cautionary': {'fear': 1},
#  'cautious': {'positive': 1, 'anticipation': 1, 'fear': 1, 'trust': 1},
#  'cautiously': {'positive': 1, 'fear': 1},
#  'cede': {'negative': 1},
#  'celebrated': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'celebrating': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'celebration': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'celebrity': {'disgust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'trust': 1,
#   'positive': 1,
#   'surprise': 1,
#   'anger': 1,
#   'negative': 1},
#  'celestial': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'cement': {'anticipation': 1, 'trust': 1},
#  'cemetery': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'censor': {'trust': 1, 'disgust': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'censure': {'negative': 1},
#  'center': {'positive': 1, 'trust': 1},
#  'centurion': {'positive': 1},
#  'cerebral': {'positive': 1},
#  'ceremony': {'positive': 1, 'joy': 1, 'surprise': 1},
#  'certainty': {'positive': 1},
#  'certify': {'trust': 1},
#  'cess': {'disgust': 1, 'negative': 1},
#  'cessation': {'negative': 1},
#  'chaff': {'negative': 1, 'anger': 1, 'fear': 1},
#  'chafing': {'negative': 1},
#  'chagrin': {'sadness': 1, 'disgust': 1, 'negative': 1},
#  'chairman': {'positive': 1, 'trust': 1},
#  'chairwoman': {'positive': 1, 'trust': 1},
#  'challenge': {'negative': 1, 'anger': 1, 'fear': 1},
#  'champion': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'chance': {'surprise': 1},
#  'chancellor': {'trust': 1},
#  'change': {'fear': 1},
#  'changeable': {'anticipation': 1, 'surprise': 1},
#  'chant': {'positive': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'anger': 1,
#   'surprise': 1},
#  'chaos': {'sadness': 1, 'negative': 1, 'anger': 1, 'fear': 1},
#  'chaotic': {'anger': 1, 'negative': 1},
#  'chaplain': {'trust': 1},
#  'charade': {'negative': 1},
#  'chargeable': {'sadness': 1, 'fear': 1, 'negative': 1},
#  'charger': {'positive': 1},
#  'charitable': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'charity': {'positive': 1, 'joy': 1},
#  'charm': {'positive': 1},
#  'charmed': {'positive': 1, 'joy': 1, 'negative': 1},
#  'charming': {'positive': 1},
#  'chart': {'trust': 1},
#  'chase': {'negative': 1},
#  'chasm': {'fear': 1},
#  'chastisement': {'negative': 1},
#  'chastity': {'positive': 1, 'anticipation': 1, 'trust': 1},
#  'chattering': {'positive': 1},
#  'chatty': {'negative': 1},
#  'cheap': {'negative': 1},
#  'cheat': {'disgust': 1, 'anger': 1, 'negative': 1},
#  'checklist': {'positive': 1, 'trust': 1},
#  'cheer': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'cheerful': {'positive': 1, 'joy': 1, 'surprise': 1},
#  'cheerfulness': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'cheering': {'positive': 1, 'joy': 1},
#  'cheery': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'cheesecake': {'negative': 1},
#  'chemist': {'positive': 1, 'trust': 1},
#  'cherish': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'cherry': {'positive': 1},
#  'chicane': {'trust': 1, 'anticipation': 1, 'negative': 1, 'surprise': 1},
#  'chicken': {'fear': 1},
#  'chieftain': {'positive': 1},
#  'child': {'positive': 1, 'anticipation': 1, 'joy': 1},
#  'childhood': {'positive': 1, 'joy': 1},
#  'childish': {'negative': 1},
#  'chilly': {'negative': 1},
#  'chimera': {'fear': 1, 'surprise': 1},
#  'chirp': {'positive': 1, 'joy': 1},
#  'chisel': {'positive': 1},
#  'chivalry': {'positive': 1},
#  'chloroform': {'negative': 1},
#  'chocolate': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'choice': {'positive': 1},
#  'choir': {'positive': 1, 'joy': 1, 'trust': 1},
#  'choke': {'sadness': 1, 'anger': 1, 'negative': 1},
#  'cholera': {'sadness': 1, 'disgust': 1, 'fear': 1, 'negative': 1},
#  'chop': {'negative': 1},
#  'choral': {'positive': 1, 'joy': 1},
#  'chore': {'negative': 1},
#  'chorus': {'positive': 1},
#  'chosen': {'positive': 1},
#  'chowder': {'positive': 1},
#  'chronic': {'sadness': 1, 'negative': 1},
#  'chronicle': {'positive': 1, 'trust': 1},
#  'chuckle': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'church': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'cider': {'positive': 1},
#  'cigarette': {'negative': 1},
#  'circumcision': {'positive': 1},
#  'circumvention': {'positive': 1, 'negative': 1},
#  'citizen': {'positive': 1},
#  'civil': {'positive': 1},
#  'civility': {'positive': 1},
#  'civilization': {'positive': 1, 'trust': 1},
#  'civilized': {'positive': 1, 'joy': 1, 'trust': 1},
#  'claimant': {'disgust': 1, 'anger': 1},
#  'clairvoyant': {'positive': 1},
#  'clamor': {'surprise': 1,
#   'disgust': 1,
#   'anticipation': 1,
#   'anger': 1,
#   'negative': 1},
#  'clan': {'trust': 1},
#  'clap': {'positive': 1, 'anticipation': 1, 'joy': 1, 'trust': 1},
#  'clarify': {'positive': 1},
#  'clash': {'anger': 1, 'negative': 1},
#  'clashing': {'negative': 1, 'anger': 1, 'fear': 1},
#  'classic': {'positive': 1},
#  'classical': {'positive': 1},
#  'classics': {'positive': 1, 'joy': 1},
#  'classify': {'positive': 1},
#  'claw': {'negative': 1, 'anger': 1, 'fear': 1},
#  'clean': {'positive': 1, 'joy': 1, 'trust': 1},
#  'cleaning': {'positive': 1},
#  'cleanliness': {'positive': 1},
#  'cleanly': {'positive': 1},
#  'cleanse': {'positive': 1},
#  'cleansing': {'positive': 1},
#  'clearance': {'positive': 1, 'trust': 1},
#  'clearness': {'positive': 1},
#  'cleave': {'fear': 1},
#  'clerical': {'positive': 1, 'trust': 1},
#  'clever': {'positive': 1},
#  'cleverness': {'positive': 1},
#  'cliff': {'fear': 1},
#  'climax': {'positive': 1,
#   'trust': 1,
#   'anticipation': 1,
#   'joy': 1,
#   'surprise': 1},
#  'clock': {'anticipation': 1},
#  'cloister': {'negative': 1},
#  'closeness': {'positive': 1, 'joy': 1, 'trust': 1},
#  ...}

# %% [markdown]
# ## Text Sentiment
# All of the sentiment analysis is based on the individual _words_ in the text. Thus you will need to will determine which words in a tweet have which sentiments.
#
# - Note that the assignment explicitly does _not_ tell you what to name functions, what arguments they should take or values they should return: your task is to determine appropriate functions and arguments from the (guided) requirements! Use multiple functions for clarity, give them all informative names, and include a **doc string** to explain what each does.

# %% [markdown]
# Define a function that take a tweet's text (a string) and splits it up into a list of individual words.
#
# - You should **not** use the `nltk` library to tokenize words. Instead, your analysis should split up the text using the [regular expression](https://www.regular-expressions.info/) **`"\W+"`** as a separator to "split up" the words by (rather than just a blank space). You can do this by using the [re.split()](https://docs.python.org/3/library/re.html#re.split) function (from the `re` module). This separator will cause your spitting to exclude punctuation and provide a reasonable (but not perfect!) list of words to consider.
#
# - All of the words in the sentiment dictionary are _lower case_, so you'll need to **map** your resulting words to be lower case. You will also need to **filter** out any words that have 1 letter or fewer. Your function must use a **list comprehension** to do this.
#
# The string `"Amazingly, I prefer a #rainy day to #sunshine."` should produce a list with 6 lower-case words in it.

# %%
'''
import re

def lowertext(t):
    lowert = t.lower()
    return lowert

def split_text(text):
    individualwords = re.split('\W+',text)
    doc = []
    for i in individualwords:
        lower = lowertext(i)
        if len(lower)>1:
            doc.append(lower)         
    return doc
split_text('Amazingly, I prefer a #rainy day to #sunshine.')    
'''
# Out:
# "\nimport re\n\ndef lowertext(t):\n    lowert = t.lower()\n    return lowert\n\ndef split_text(text):\n    individualwords = re.split('\\W+',text)\n    doc = []\n    for i in individualwords:\n        lower = lowertext(i)\n        if len(lower)>1:\n            doc.append(lower)         \n    return doc\nsplit_text('Amazingly, I prefer a #rainy day to #sunshine.')    \n"

# %%
import re
def text_to_word(string):
    word_list = re.split(r'\W+', string)
    word_list = list(map(lambda x:x.lower(),word_list))
    word_list = list(filter(lambda x: len(x)>1,word_list))
    return word_list
text_to_word("Amazingly, I prefer a #rainy day to #sunshine.")
# Out:
# ['amazingly', 'prefer', 'rainy', 'day', 'to', 'sunshine']

# %% [markdown]
# Define a function that **filters** a list of the words to get only those words that contain a specific emotion. Your function must use a **list comprehension** to do this.
# - You can determine whether a word has a particular emotion by looking it up in the imported `SENTIMENTS` variable. Use the word as the "key" to find the dictionary of emotions for that word, and then use the emotion as the key to _that_ dictionary to determine if the word has it.
#
#     Do **not** use the `in` operator or a loop to search the list of keys one by one. Instead, use bracket notation or the `get()` method to "look up" a key directly (this is more efficient and is why the emotions are nested dictionaries in the first place!).
#
# For testing, the `"positive"` words extracted from `"Amazingly, I prefer a #rainy day to #sunshine."` are `["amazingly", "prefer", "sunshine"]`.

# %%
'''
def emotion_word(sentence,emotion):
    wordlist = split_text(sentence)
    sentimentlist =[]
    for i in wordlist:
        if SENTIMENTS.get(i) is not None and SENTIMENTS.get(i).get(emotion)==1:
            sentimentlist.append(i)
    #print(positivelist)
    return sentimentlist
emotion_word("Amazingly, I prefer a #rainy day to #sunshine.","positive")
'''
# Out:
# '\ndef emotion_word(sentence,emotion):\n    wordlist = split_text(sentence)\n    sentimentlist =[]\n    for i in wordlist:\n        if SENTIMENTS.get(i) is not None and SENTIMENTS.get(i).get(emotion)==1:\n            sentimentlist.append(i)\n    #print(positivelist)\n    return sentimentlist\nemotion_word("Amazingly, I prefer a #rainy day to #sunshine.","positive")\n'

# %%
def word_to_emotion(string, emotion):
    emotion_list = []
    for word in text_to_word(string):
        # to solve the error of "'NoneType' object has no attribute 'get'"
        if SENTIMENTS.get(word,None)!= None:
            if SENTIMENTS.get(word,None).get(emotion) == 1:
                emotion_list.append(word)
    return emotion_list
word_to_emotion("Amazingly, I prefer a #rainy day to #sunshine.",'positive')
# Out:
# ['amazingly', 'prefer', 'sunshine']

# %% [markdown]
# Define a function that determines which words from a list have _each_ emotion (i.e., the "emotional" words), producing a dictionary of that information. For example, the words extracted from `"Amazingly, I prefer a #rainy day to #sunshine."` should produce a dictionary that looks like:
#
# ```
# {
#  'anger': [],
#  'anticipation': [],
#  'disgust': [],
#  'fear': [],
#  'joy': ['amazingly', 'sunshine'],
#  'negative': [],
#  'positive': ['amazingly', 'prefer', 'sunshine'],
#  'sadness': ['rainy'],
#  'surprise': ['amazingly'],
#  'trust': ['prefer']
# }
# ```
#
# (Note the empty lists for emotions that have no matching words).
#
# - You can use the imported `EMOTIONS` variable to have a list of emotions to iterate through.
# - Use the function you defined in the previous step to help you out!
# - Using a [dictionary comprehension](https://www.smallsurething.com/list-dict-and-set-comprehensions-by-example/) is a nice way to do this, but is not required.

# %%
'''
emodic = {}
def emotionlist(text):
    wordlist = split_text(text)
    for i in EMOTIONS:
        #Build the keyset for the emodic
        emodic[i]=[]
    for i in wordlist:
        #Iterate the wordlist, check if the sentiments have the key of i
        if SENTIMENTS.get(i) is not None:
            #for each i, we iterate the keyset of key i in Sentiments
            for j in SENTIMENTS.get(i).keys():
                #Add each word i to the corresponding list in emodic
                emodic.get(j).append(i)
    return emodic
emotionlist("Amazingly, I prefer a #rainy day to #sunshine.")
'''
# Out:
# '\nemodic = {}\ndef emotionlist(text):\n    wordlist = split_text(text)\n    for i in EMOTIONS:\n        #Build the keyset for the emodic\n        emodic[i]=[]\n    for i in wordlist:\n        #Iterate the wordlist, check if the sentiments have the key of i\n        if SENTIMENTS.get(i) is not None:\n            #for each i, we iterate the keyset of key i in Sentiments\n            for j in SENTIMENTS.get(i).keys():\n                #Add each word i to the corresponding list in emodic\n                emodic.get(j).append(i)\n    return emodic\nemotionlist("Amazingly, I prefer a #rainy day to #sunshine.")\n'

# %%
def emotions_in_word(string):
    dict = {}
    for emo in EMOTIONS:
        dict[emo] = word_to_emotion(string, emo)
    return dict
emotions_in_word("Amazingly, I prefer a #rainy day to #sunshine.")
# Out:
# {'positive': ['amazingly', 'prefer', 'sunshine'],
#  'negative': [],
#  'anger': [],
#  'anticipation': [],
#  'disgust': [],
#  'fear': [],
#  'joy': ['amazingly', 'sunshine'],
#  'sadness': ['rainy'],
#  'surprise': ['amazingly'],
#  'trust': ['prefer']}

# %% [markdown]
# Define a function that gets a list of the "most common" words in a list. This should be a new list containing each word in the original list, in descending order by how many times that word appears in the orignal list.
#
# - You can determine the frequency (number of occurrences) of a word with a similar process to what you did with digits in the previous assignment.
# - You should use the `sorted()` function to [sort](https://wiki.python.org/moin/HowTo/Sorting) the individual words. This function take a **`key`** argument which should be passed a [_callback function_](https://wiki.python.org/moin/HowTo/Sorting#Key_Functions) that can return a "transformed" value that you wish to sort by (e.g., which element in a tuple). An anonymous lambda function works well for this.
#
# You can test this function with any list of "words" with repeated entries: `['a','b','c','c','c','a']` for example.

# %%
'''
from collections import Counter
import operator

def word_count(t):
    my_string = t
    my_dict = {}
    for item in my_string:
        if item in my_dict:
            my_dict[item] += 1
        else:
            my_dict[item] = 1
    return my_dict
word_count(['aba','baa','cdd','cee','cee','aba'])

def word_frequency(original_list):
    newlist = Counter()
    for i in original_list:
        newlist[i]+=1
    return newlist
word_frequency(['aba','baa','cdd','cee','cee','aba'])  

l = dict(word_frequency(['aba','baa','cdd','cee','cee','aba']))
l.values()

sorted_l = dict(sorted(l.items(), key=lambda kv: kv[1],reverse=True))
sorted_l
'''

# %%
def word_frequency(alist):
    dict = {}
    for item in alist:
        if not item in dict:
            dict[item] = alist.count(item)
    sorted_items = sorted(dict.items(),key=lambda x: x[1],reverse=True)
    return sorted_items

word_frequency(['a','b','c','c','c','a'])
# Out:
# [('c', 3), ('a', 2), ('b', 1)]

# %% [markdown]
# ## Tweet Statistics
# Once you are able to determine the sentiment of an individual string of text (e.g., a single tweet's content), you can analyze an entire set of tweets from the user's timeline. Note that I am _not_ telling you how to break this process up into individual functions&mdash;you should be able to determine that on your own by this point!

# %% [markdown]
# Define a function (e.g., `analyze_tweets()`) that takes as an argument a **list** of tweet data (with the same structure as the imported `SAMPLE_TWEETS` variable), and _returns_ the data of interest to display in a table like the one at the very top of the notebook. In particular, you'll need to produce the following information **for each emotion**:
#
# 1. The percentage of words _across all tweets_ that have that emotion
# 2. The most common words _across all tweets_ that have that emotion (in order!)
#
# (Think carefully: should this data be stored in a _list_ or a _dictionary_?)
#
# Some tips for this task:
#
# - You can and should create some "helper" functions to break up this task even further. You can define those functions in the same notebook cell or you may insert additional cells.
#
# - You'll need to use your previous functions to get the _list of words_ and _dictionary of emotional words_ for each tweet. I recommend you assign the results of these methods as **new values** of the respective tweet dictionary (so each tweet dictionary would gain a `words` key, for example).
#
# - In order to get the percentage of emotional words, divide the number of words that have that emotion by the total number of words _across all the tweets_. Counting how many total words are in the tweet set is a **reducing** operation: you should use the `reduce()` function for this.
#
# - For each emotion, you'll need to get a list of the words _across all the tweets_ that have that emotion (in order to determine how many there are for the percentage, as well as which are most common). This is another **reducing** operation; you should use the `reduce()` function to _add up_ all of these words (alternatively, the built-in `sum()` function can be used here).
#
# You can test your function by passing in the `SAMPLE_TWEETS` variable as an argument and checking if your returned data has the same numbers as in the table at the top of the page. Note that only the first 3 most common words are listed in the example (and may be in a different order in the case of frequency ties!).

# %%
allwords=[]
def getAllWords(t):
    for i in t:
        tempwords=split_text(i)
        for j in tempwords:
            allwords.append(j)
    return allwords

# %%
sample_list = []
for i in SAMPLE_TWEETS:
    sample_list.append(i['text'])
sample_list

getAllWords(sample_list)

# %%
len(getAllWords(sample_list))

# %%
emomo = []
def getEmotions(ListofWords):   
    for i in ListofWords:
        if i in SENTIMENTS.keys():
            emomo.append(i)
    return emomo
getEmotions(getAllWords(sample_list))

# %%
len(emomo)

# %%
emotionset = set()
def analyze_tweets(listofwords):
    
    emotiondic = {}
    emotionstat = {}
    totalwords = len(listofwords)
    for i in emomo:
        for j in SENTIMENTS.get(i):
            emotionset.add(j)
    # build the emotion percentage
    for i in emotionset:
        emotionstat[i] = 0
        for j in emomo:
            if SENTIMENTS.get(j).get(i) is not None:
                emotionstat[i]+=1
    for i in emotionset:
        emotiondic[i] = []
        for j in emomo:
            if SENTIMENTS.get(j).get(i) is not None and j not in emotiondic[i]:
                emotiondic[i].append(j)
    for i in emotionstat.keys():
        emotionstat[i] = '{percent:.2%}'.format(percent=emotionstat[i]/totalwords)
    return emotionstat,emotiondic
analyze_tweets(getAllWords(sample_list))

# %%
for i in analyze_tweets(getAllWords(sample_list))[0].keys():
    print(i)
for k in analyze_tweets(getAllWords(sample_list))[0].values():
    print(k)
for j in analyze_tweets(getAllWords(sample_list))[1].values():
    print(j[:3])

# %%
from functools import reduce

def count_total(text_list):
    whole_list = [text_to_word(item) for item in text_list]
    return len(reduce(lambda x, y: x+y, whole_list))

def emotions_in_hashtag(string,hashtag):
    emodic = emotions_in_word('')
    for emo in EMOTIONS:
        emodic[emo] = word_to_emotion(string,emo)
        if len(emodic[emo]) > 0:
            emodic[emo] = hashtag
    return emodic

def get_table(text_list,hashtag_list):
    ans = emotions_in_word('')
    ans_hash = emotions_in_word('')
    for i in range(len(text_list)):
        dict_emotion = emotions_in_word(text_list[i])
        dict_emotion_hashtag = emotions_in_hashtag(text_list[i],hashtag_list[i])
        for emo in EMOTIONS:
            ans[emo] += dict_emotion[emo]
            ans_hash[emo] += dict_emotion_hashtag[emo]

    dict_word_freq = emotions_in_word('')
    dict_hash_freq = emotions_in_word('')
    table_dict = {}
    total_words = count_total(text_list)
    for emo in EMOTIONS:
        dict_word_freq[emo] = word_frequency(ans[emo])
        dict_hash_freq[emo] = word_frequency(ans_hash[emo]) 
        # "if": to solve the error of "reduce() of empty sequence with no initial value"
        if dict_word_freq[emo]!=[]: 
            eg_words = reduce(lambda x,y:x + ', ' + y,[dict_word_freq[emo][i][0] for i in range(len(dict_word_freq[emo])) if i < 3])
        if dict_hash_freq[emo]!=[]:
            eg_hashtags = reduce(lambda x,y:x + ', ' + y,[dict_hash_freq[emo][i][0] for i in range(len(dict_hash_freq[emo])) if i < 3])
        if dict_word_freq[emo]!=[]:
            table_dict[emo] = reduce(lambda x,y:x + y,[i[1] for i in dict_word_freq[emo]])
        table_dict[emo] = [table_dict[emo]/total_words,eg_words,eg_hashtags]
    return table_dict


def analyze_tweets(SAMPLE_TWEETS):
    tweets_list = [tweet['text'] for tweet in SAMPLE_TWEETS]
    hashtags = []
    for i in SAMPLE_TWEETS:
        temp = []
        for j in i['entities']['hashtags']:
                temp.append('#' + j['text'].lower())
        hashtags.append(temp)
    table_dict=get_table(tweets_list,hashtags)
    sorted_table = sorted(table_dict.items(), key=lambda x: x[1],reverse=True)
    return sorted_table
analyze_tweets(SAMPLE_TWEETS)
# Out:
# [('positive',
#   [0.061606160616061605,
#    'learn, faculty, happy',
#    '#accesstoinfoday, #indigenouspeoplesday, #idealistfair']),
#  ('trust',
#   [0.030803080308030802,
#    'school, faculty, happy',
#    '#indigenouspeoplesday, #diversity']),
#  ('anticipation',
#   [0.025302530253025302,
#    'happy, top, ready',
#    '#indigenouspeoplesday, #informatics, #info340']),
#  ('joy',
#   [0.0176017601760176,
#    'happy, peace, deal',
#    '#indigenouspeoplesday, #accesstoinfoday']),
#  ('surprise',
#   [0.009900990099009901,
#    'deal, award, surprised',
#    '#suzzallolibrary, #nobrainer']),
#  ('negative',
#   [0.0088008800880088,
#    'fall, rejection, outstanding',
#    '#accesstoinfoday, #indigenouspeoplesday, #idealistfair']),
#  ('sadness',
#   [0.005500550055005501,
#    'fall, rejection, problem',
#    '#indigenouspeoplesday, #accesstoinfoday']),
#  ('disgust',
#   [0.0044004400440044,
#    'rejection, weird, finally',
#    '#indigenouspeoplesday, #informatics, #info340']),
#  ('fear',
#   [0.0044004400440044,
#    'rejection, surprise, problem',
#    '#indigenouspeoplesday, #informatics, #info340']),
#  ('anger',
#   [0.0033003300330033004, 'rejection, disaster, involvement', '#mlis'])]

# %% [markdown]
# ### Displaying Tweets
#
# Once you've analyzed the tweets, you will need to _display_ that information as a printed table (as in the example at the top of the page).
#
# Define another function to display this table (your function should take as an argument the data structure returned from your "analysis" function).
#
# This function will need to print out the table. Using the [string formatting](https://docs.python.org/3/library/string.html#format-examples) language (via the **`.format()`** string method) makes it possible to have equally sized "columns" of data. For more examples, [this tutorial](https://www.digitalocean.com/community/tutorials/how-to-use-string-formatters-in-python-3) is pretty good (check out the "Padding Variable Substitutions" section).
#
#
# A few notes about formatting this output:
#
# - For your reference, the example table at the top of the page uses `14` characters for the first column, `11` characters for the second,  `35` for the third, and the "remainder" for the fourth. You are not required to match these numbers.
#
# - The percentage should be formatted with two decimals of precision (e.g., `1.23%`).
#
# - Both the example sentiment words (and the hashtags, if you include them) should be outputted as a _comma-separated list_ with spaces between them&mdash;and no square brackets). The `join()` string method is good for converting lists to formatted strings. Both lists should also be limited to the 3 most common items for space.
#
# - Make sure to include `#` in front of the hashtags!
#
# - You should **sort** the emotions by percentage of words (descending), as in the example at the top.

# %%
'''
def showEmotionData():
    print('{0:<14}\t{1:<11}\t{2:<35}'.format("EMOTION", "% WORDS","EXAMPLE WORDS"))
    for i in analyze_tweets(getAllWords(sample_list))[1].values():
        print('{0:<14}\t{1:<11}\t{2:<35}'.format(i[:3], "% WORDS","EXAMPLE WORDS")) 

showEmotionData()
'''
# Out:
# '\ndef showEmotionData():\n    print(\'{0:<14}\t{1:<11}\t{2:<35}\'.format("EMOTION", "% WORDS","EXAMPLE WORDS"))\n    for i in analyze_tweets(getAllWords(sample_list))[1].values():\n        print(\'{0:<14}\t{1:<11}\t{2:<35}\'.format(i[:3], "% WORDS","EXAMPLE WORDS")) \n\nshowEmotionData()\n'

# %%
def print_table(tweetlist):
    print("{:13s} {:8s} {:34} {:40s}".format('EMOTION','% WORDS','EXAMPLE WORDS','HASHTAGS'))
    for tweet in tweetlist:
        print("{:12s} {:5.2f}%    {:34} {:40s}".format(tweet[0],tweet[1][0]*100,tweet[1][1],tweet[1][2]))
print_table(analyze_tweets(SAMPLE_TWEETS))
# Out:
# EMOTION       % WORDS  EXAMPLE WORDS                      HASHTAGS
# positive      6.16%    learn, faculty, happy              #accesstoinfoday, #indigenouspeoplesday, #idealistfair
# trust         3.08%    school, faculty, happy             #indigenouspeoplesday, #diversity
# anticipation  2.53%    happy, top, ready                  #indigenouspeoplesday, #informatics, #info340
# joy           1.76%    happy, peace, deal                 #indigenouspeoplesday, #accesstoinfoday
# surprise      0.99%    deal, award, surprised             #suzzallolibrary, #nobrainer
# negative      0.88%    fall, rejection, outstanding       #accesstoinfoday, #indigenouspeoplesday, #idealistfair
# sadness       0.55%    fall, rejection, problem           #indigenouspeoplesday, #accesstoinfoday
# disgust       0.44%    rejection, weird, finally          #indigenouspeoplesday, #informatics, #info340
# fear          0.44%    rejection, surprise, problem       #indigenouspeoplesday, #informatics, #info340
# anger         0.33%    rejection, disaster, involvement   #mlis

# %% [markdown]
# ## Getting Live Data
# This is all good and well, but the real payoff is to be able to see the sentiments of tweets taken directly from the Twitter feed of real users!

# %% [markdown]
# Define _another_ function that takes in a Twitter username as an argument and then returns a list of dictionaries representing the tweets made by that user.
#
# Normally you would fetch this data by sending a request directly to the web service's API (e.g., to the the [statuses/user_timeline](https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline) endpoint provided by the Twitter API at `https://api.twitter.com/1.1/statuses/user_timeline`). However, Twitter includes access controls so that only registered developers are allowed to send requests. While it is possible to register as a developer and access Twitter [directly through Python](https://python-twitter.readthedocs.io/en/latest/), this adds an extra level of complexity to the assignment.
#
# Instead, I've set up a [proxy](https://en.wikipedia.org/wiki/Proxy) that has all the access keys specified which you can use to search Twitter. This proxy is available at:
#
# **<https://faculty.washington.edu/joelross/proxy/twitter/timeline/>**
#
# Send a request to _that_ url instead of `https://api.twitter.com/1.1/statuses/user_timeline`, and it will redirect your request with the proper authentication to Twitter, and then give you back whatever JSON Twitter's API responded with.
#
# - You specify the same request parameters as you would when accessing Twitter directly. The request takes a `screen_name` request parameter which you can assign the given username. You can also specify the `count` parameter if you want to get more results back (up to 200); see the [documentation](https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline) for details and other options you are welcome to use (just document them in your function's **docstring**).
#
# - **WARNING:** The proxy I have set up is **rate-limited** so that it can only accept 900 requests every 15 minutes. If all 40 students are working rapidly on the assignment at the same time, you may find yourself needing to wait a few minutes and try again. You are alternatively welcome to set up your own developer account and API keys; just make sure you don't put the keys under version control and upload them to GitHub!
#
# You can download the timeline data from Twitter using the [requests](http://docs.python-requests.org/en/master/user/quickstart/) module: send a `GET` request to the [statuses/user_timeline](https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline) endpoint provided by the Twitter API, and then use the `.json()` method to extract the JSON response as a Python _list_ or _dictionary_ value you can work with.

# %%
'''import re
import requests
from functools import reduce
def download(username):
    screen_name = {'screen_name': username}
    r = requests.get('https://faculty.washington.edu/joelross/proxy/twitter/timeline', params=screen_name)
    return r.json()
    '''
# Out:
# "import re\nimport requests\nfrom functools import reduce\ndef download(username):\n    screen_name = {'screen_name': username}\n    r = requests.get('https://faculty.washington.edu/joelross/proxy/twitter/timeline', params=screen_name)\n    return r.json()\n    "

# %%
import requests
def download_tweets(UserName,count):
    response = requests.get('https://faculty.washington.edu/joelross/proxy/twitter/timeline?screen_name='+UserName+'&count='+str(count))
    return response.json()

# %% [markdown]
# Define one last "main" function that will [prompt the user](https://docs.python.org/3/library/functions.html#input) for a Twitter username. The function should then call your "download" function to fetch the tweets, and pass the returned tweet data into your "analyze" and "show" functions in order to display your sentiment analysis of the user's timeline.
#
# **ADDITIONALLY**, `if` the user specifies `SAMPLE` (all caps) as the username, the function should instead show the analysis for the `SAMPLE_TWEETS` (this will help us out with grading).

# %%
def main():
    UserName = input('user name: ')
    if UserName =='SAMPLE':
        print_table(analyze_tweets(SAMPLE_TWEETS))
    else:
        count = input('number of tweets to be analyzed: ')
        tweets = download_tweets(UserName,count)
        print_table(analyze_tweets(tweets))
main()
# Out:
# Please input user name: UW_iSchool
# Please input number of tweets to be analyzed: 50
# EMOTION       % WORDS  EXAMPLE WORDS                      HASHTAGS
# positive      6.39%    working, technology, talk          #accesstoinformation, #da2i, #ischoolcapstone
# trust         3.65%    team, good, present                #da2i, #ischoolcapstone, #accesstoinformation
# joy           2.23%    good, present, create              #accesstoinformation, #da2i, #comicbooks
# anticipation  1.93%    good, present, engaged             #ischoolcapstone, #accesstoinformation, #da2i
# surprise      1.42%    good, present, lucky               #da2i, #datascience, #accesstoinformation
# negative      0.81%    compulsion, hate, combat           #facebook
# fear          0.71%    hate, combat, defense              #ischoolcapstone, #accesstoinformation, #facebook
# sadness       0.51%    music, hate, missing               #als
# anger         0.51%    compulsion, hate, combat           #ischoolcapstone
# disgust       0.10%    hate                               #ischoolcapstone, #accesstoinformation, #da2i

# %% [markdown]
# Use your main function to try analyzing the timelines of different users and comparing their results. Are the current sentiments of the [iSchool](https://twitter.com/uw_ischool) and [CSE](https://twitter.com/uwcse) different in interesting ways?

# %%
main()
# Out:
# Please input user name: uwcse
# Please input number of tweets to be analyzed: 50
# EMOTION       % WORDS  EXAMPLE WORDS                      HASHTAGS
# positive      7.41%    learn, received, supporting        #uwallen, #ai, #cg
# trust         4.29%    team, supporting, award            #uwallen, #ai, #cg
# joy           2.34%    award, present, outstanding        #uwallen, #ai, #cg
# anticipation  2.34%    award, present, explore            #uwallen, #ai, #realitylablecture
# negative      1.17%    late, outstanding, superficial     #uwallen, #realitylablecture, #ar
# surprise      1.17%    award, present, exciting           #uwallen, #cg
# sadness       0.49%    late, interested, missing          #uwallen
# fear          0.39%    challenge, fight, graduation       #realitylablecture, #ar, #vr
# disgust       0.29%    interested, excellence, shameless  #ai, #uwallen
# anger         0.19%    challenge, fight                   #realitylablecture, #ar, #vr

# %%
'''The codes that being commented are my initial thoughts and just kept for reference. Do not need to run them'''
